# %%
"""
####################
# Project-1
####################
1- baisc data load
2- How to find matrix using (linear regression)
"""

# %% [markdown]
# | Hours | Score |
# | --- | --- |
# | 1 | 52 |
# | 2 | 57 |
# | 3 | 65 |
# | 4 | 70 |
# | 5 | 75 |
# | 6 | 80 |
#
# ```

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

data = pd.read_csv('student.csv')
X = data[['Hours']]
Y = data['Score']

model = LinearRegression()
model.fit(X,Y)

predicted_score=model.predict(X)

# Evaluate
mae = mean_absolute_error(Y, predicted_score)
mse = mean_squared_error(Y, predicted_score)
rmse = np.sqrt(mse)

# Showing Results
print(f"Mean Absolute ERROR (MAE):{mae}")
print(f"Mean Squared ERROR (MSE):{mse}")
print(f"Mean Squared ERROR (MAE):{rmse}")

new_hour = float(input("Enter an hour: "))
new_pred = model.predict([[new_hour]])

print(f"Prediction for {new_hour} = {new_pred}")
# Out:
# Mean Absolute ERROR (MAE):0.6666666666666643
# Mean Squared ERROR (MSE):0.6285714285714282
# Mean Squared ERROR (MAE):0.7928249671720916
# Prediction for 7.0 = [86.4]
# c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
